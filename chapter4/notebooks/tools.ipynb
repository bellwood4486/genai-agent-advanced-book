# %% [markdown]
# ## マニュアル検索ツール

# %%
from src.tools.search_xyz_manual import search_xyz_manual

result = search_xyz_manual.invoke("オンラインヘルプセンター")
print(result[0].content)
# Out:
# 2026-04-01 22:26:16,811 INFO Searching XYZ manual by keyword: オンラインヘルプセンター
# 2026-04-01 22:26:17,070 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.258s]
# 2026-04-01 22:26:17,071 INFO Search results: 1 hits
# 2026-04-01 22:26:17,072 INFO Finished searching XYZ manual by keyword
# ます。
# オンラインヘル プセンター：24時間365 ⽇利⽤可能なヘル プセンター では、シ ス
# テムの使⽤⽅法や⼀般的な問題に関す る問い合わせを受け付けています 。
# 定期的なウェビ ナー：新機能の紹介や⾼度な使⽤テクニックを学ぶためのオン
# ラインセミナーを開催し ています 。
# 2. システムへのアクセスとログイン
# XYZシステムへのア クセスとログ インは、システムを利⽤する上で最初のステッ プで
# す。この章では、安全かつ効率的にシ ステムにアクセスし、ログ インする⽅法につ
# いて詳しく説明します 。セキュリテ ィを確保しながら、スム ーズにシステムを利⽤開

# %%
result

# %% [markdown]
# ## 過去QA検索ツール

# %%
from src.tools.search_xyz_qa import search_xyz_qa

result = search_xyz_qa.invoke("パスワードを間違えてロックされました")
print(result[0].content)
# Out:
# 2026-04-01 22:34:15,491 INFO Searching XYZ QA by query: パスワードを間違えてロックされました
# 2026-04-01 22:34:15,630 INFO Generating embedding vector from input query
# 2026-04-01 22:34:18,153 INFO HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-04-01 22:34:18,246 INFO HTTP Request: POST http://localhost:6333/collections/documents/points/query "HTTP/1.1 200 OK"
# 2026-04-01 22:34:18,248 INFO Search results: 3 hits
# 2026-04-01 22:34:18,249 INFO Finished searching XYZ QA by query
# Q:パスワードを所定回数間違えてログインがロックされた場合の対処法を教えていただけますか
# A:パスワードを所定回数間違えてログインがロックされた場合は、以下の手順で対処してください：
# システム管理者に連絡
# ロックアウトの解除には管理者権限が必要です。システム管理者に状況を説明し、ロック解除を依頼してください。
# 本人確認
# 管理者は、セキュリティ上の理由から、ユーザーの身元を確認します。必要な情報を提供してください。
# 一時的なパスワードの発行
# 管理者が一時的なパスワードを発行します。これを使用して再度ログインしてください。
# パスワードの変更
# ログイン後、すぐに新しいパスワードに変更してください。セキュリティのため、以前のパスワードとは異なるものを選択してください。
# セキュリティ設定の確認
# アカウントのセキュリティ設定を確認し、必要に応じて多要素認証などの追加セキュリティ措置を有効にすることを検討してください。
