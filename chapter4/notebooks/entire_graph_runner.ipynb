# %%
from src.agent import HelpDeskAgent
from src.configs import Settings
from src.tools.search_xyz_manual import search_xyz_manual
from src.tools.search_xyz_qa import (
    search_xyz_qa,
)

# %%
settings = Settings()

# %%
agent = HelpDeskAgent(
    settings=settings,
    tools=[search_xyz_manual, search_xyz_qa],
)

# %%
# question = """
# お世話になっております。

# 現在、XYZシステムの利用を検討しており、以下の2点についてご教示いただければと存じます。

# 1. パスワードに利用可能な文字の制限について
# 当該システムにてパスワードを設定する際、使用可能な文字の範囲（例：英数字、記号、文字数制限など）について詳しい情報をいただけますでしょうか。安全かつシステムでの認証エラーを防ぐため、具体的な仕様を確認したいと考えております。

# 2. 最新リリースの取得方法について
# 最新のアップデート情報をどのように確認・取得できるかについてもお教えいただけますと幸いです。

# お忙しいところ恐縮ですが、ご対応のほどよろしくお願い申し上げます。

# """

question = """
お世話になっております。

現在、XYZシステムを利用しており、以下の点についてご教示いただければと存じます。

1. 特定のプロジェクトに対してのみ通知を制限する方法について
特定のプロジェクトに対してのみ通知を制限する方法についてお教えいただけますと幸いです。

2. パスワードに利用可能な文字の制限について
当該システムにてパスワードを設定する際、使用可能な文字の範囲（例：英数字、記号、文字数制限など）について詳しい情報をいただけますでしょうか。安全かつシステムでの認証エラーを防ぐため、具体的な仕様を確認したいと考えております。

お忙しいところ恐縮ですが、ご対応のほどよろしくお願い申し上げます。
"""

# %% [markdown]
# ## ヘルプデスクエージェント全体を実行します

# %%
result = agent.run_agent(question)
# Out:
# 2026-04-04 16:17:32,713 INFO 🚀 Starting plan generation process...
# 2026-04-04 16:17:32,713 INFO Sending request to OpenAI...
# 2026-04-04 16:17:35,523 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:35,546 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:35,546 INFO Plan generation complete!
# 2026-04-04 16:17:35,563 INFO 🚀 Starting tool selection process...
# 2026-04-04 16:17:35,563 INFO 🚀 Starting tool selection process...
# 2026-04-04 16:17:35,564 INFO 🚀 Starting tool selection process...
# 2026-04-04 16:17:35,704 INFO Sending request to OpenAI...
# 2026-04-04 16:17:35,704 INFO Sending request to OpenAI...
# 2026-04-04 16:17:35,705 INFO Sending request to OpenAI...
# 2026-04-04 16:17:36,878 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:36,884 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:36,885 INFO Tool selection complete!
# 2026-04-04 16:17:36,888 INFO 🚀 Starting tool execution process...
# 2026-04-04 16:17:36,889 INFO Searching XYZ manual by keyword: {"keywords":"パスワード 使用可能な文字"}
# 2026-04-04 16:17:36,931 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:36,934 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:36,934 INFO Tool selection complete!
# 2026-04-04 16:17:36,936 INFO 🚀 Starting tool execution process...
# 2026-04-04 16:17:36,937 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.046s]
# 2026-04-04 16:17:36,937 INFO Searching XYZ manual by keyword: {"keywords":"特定のプロジェクト 通知 制限 設定方法"}
# 2026-04-04 16:17:36,937 INFO Search results: 10 hits
# 2026-04-04 16:17:36,939 INFO Finished searching XYZ manual by keyword
# 2026-04-04 16:17:36,939 INFO Tool execution complete!
# 2026-04-04 16:17:36,940 INFO 🚀 Starting subtask answer creation process...
# 2026-04-04 16:17:36,941 INFO Sending request to OpenAI...
# 2026-04-04 16:17:36,952 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.013s]
# 2026-04-04 16:17:36,952 INFO Search results: 10 hits
# 2026-04-04 16:17:36,952 INFO Finished searching XYZ manual by keyword
# 2026-04-04 16:17:36,953 INFO Tool execution complete!
# 2026-04-04 16:17:36,954 INFO 🚀 Starting subtask answer creation process...
# 2026-04-04 16:17:36,954 INFO Sending request to OpenAI...
# 2026-04-04 16:17:37,446 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:37,450 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:37,450 INFO Tool selection complete!
# 2026-04-04 16:17:37,452 INFO 🚀 Starting tool execution process...
# 2026-04-04 16:17:37,453 INFO Searching XYZ manual by keyword: {"keywords":"パスワード 文字数制限"}
# 2026-04-04 16:17:37,497 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.042s]
# 2026-04-04 16:17:37,497 INFO Search results: 7 hits
# 2026-04-04 16:17:37,498 INFO Finished searching XYZ manual by keyword
# 2026-04-04 16:17:37,498 INFO Tool execution complete!
# 2026-04-04 16:17:37,499 INFO 🚀 Starting subtask answer creation process...
# 2026-04-04 16:17:37,499 INFO Sending request to OpenAI...
# 2026-04-04 16:17:39,365 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:39,370 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:39,370 INFO Subtask answer creation complete!
# 2026-04-04 16:17:39,373 INFO 🚀 Starting reflection process...
# 2026-04-04 16:17:39,373 INFO Sending request to OpenAI...
# 2026-04-04 16:17:40,132 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:40,133 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:40,134 INFO Subtask answer creation complete!
# 2026-04-04 16:17:40,135 INFO 🚀 Starting reflection process...
# 2026-04-04 16:17:40,135 INFO Sending request to OpenAI...
# 2026-04-04 16:17:40,437 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:40,443 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:40,443 INFO Subtask answer creation complete!
# 2026-04-04 16:17:40,446 INFO 🚀 Starting reflection process...
# 2026-04-04 16:17:40,446 INFO Sending request to OpenAI...
# 2026-04-04 16:17:40,507 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:40,516 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:40,516 INFO Reflection complete!
# 2026-04-04 16:17:41,282 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:41,286 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:41,287 INFO Reflection complete!
# 2026-04-04 16:17:41,912 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:41,917 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:41,917 INFO Reflection complete!
# 2026-04-04 16:17:41,920 INFO 🚀 Starting tool selection process...
# 2026-04-04 16:17:41,924 INFO Sending request to OpenAI...
# 2026-04-04 16:17:43,024 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:43,026 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:43,026 INFO Tool selection complete!
# 2026-04-04 16:17:43,028 INFO 🚀 Starting tool execution process...
# 2026-04-04 16:17:43,029 INFO Searching XYZ manual by keyword: {"keywords":"プロジェクト通知設定 通知制限"}
# 2026-04-04 16:17:43,053 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.024s]
# 2026-04-04 16:17:43,054 INFO Search results: 10 hits
# 2026-04-04 16:17:43,054 INFO Finished searching XYZ manual by keyword
# 2026-04-04 16:17:43,055 INFO Tool execution complete!
# 2026-04-04 16:17:43,056 INFO 🚀 Starting subtask answer creation process...
# 2026-04-04 16:17:43,056 INFO Sending request to OpenAI...
# 2026-04-04 16:17:45,648 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:45,651 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:45,651 INFO Subtask answer creation complete!
# 2026-04-04 16:17:45,654 INFO 🚀 Starting reflection process...
# 2026-04-04 16:17:45,654 INFO Sending request to OpenAI...
# 2026-04-04 16:17:47,471 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:47,475 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:47,476 INFO Reflection complete!
# 2026-04-04 16:17:47,479 INFO 🚀 Starting tool selection process...
# 2026-04-04 16:17:47,483 INFO Sending request to OpenAI...
# 2026-04-04 16:17:49,619 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:49,621 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:49,621 INFO Tool selection complete!
# 2026-04-04 16:17:49,624 INFO 🚀 Starting tool execution process...
# 2026-04-04 16:17:49,624 INFO Searching XYZ QA by query: {"query":"特定のプロジェクト 通知 制限 設定方法"}
# 2026-04-04 16:17:49,661 INFO Generating embedding vector from input query
# 2026-04-04 16:17:51,880 INFO HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-04-04 16:17:51,916 INFO HTTP Request: POST http://localhost:6333/collections/documents/points/query "HTTP/1.1 200 OK"
# 2026-04-04 16:17:51,918 INFO Search results: 3 hits
# 2026-04-04 16:17:51,919 INFO Finished searching XYZ QA by query
# 2026-04-04 16:17:51,919 INFO Tool execution complete!
# 2026-04-04 16:17:51,921 INFO 🚀 Starting subtask answer creation process...
# 2026-04-04 16:17:51,921 INFO Sending request to OpenAI...
# 2026-04-04 16:17:54,174 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:54,178 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:54,179 INFO Subtask answer creation complete!
# 2026-04-04 16:17:54,181 INFO 🚀 Starting reflection process...
# 2026-04-04 16:17:54,182 INFO Sending request to OpenAI...
# 2026-04-04 16:17:56,004 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:56,007 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:56,008 INFO Reflection complete!
# 2026-04-04 16:17:56,013 INFO 🚀 Starting final answer creation process...
# 2026-04-04 16:17:56,014 INFO Sending request to OpenAI...
# 2026-04-04 16:17:58,719 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-04 16:17:58,723 INFO ✅ Successfully received response from OpenAI.
# 2026-04-04 16:17:58,723 INFO Final answer creation complete!

# %%
# 回答
print(result.answer)
# Out:
# お世話になっております。
#
# ご質問について以下の通り回答いたします。
#
# 1. **特定のプロジェクトに対してのみ通知を制限する方法について**
#
#    現在、XYZシステムでは特定のプロジェクトに対して通知を制限する機能は提供されておりません。プロジェクト単位で通知を細かくカスタマイズすることはできませんが、通知を手動でフィルタリングすることで重要な通知だけを確認する運用が可能です。また、通知の優先度を設定し、高優先度の通知のみ表示するようにカスタマイズすることも可能です。この機能については将来的な機能要望として検討されています。
#
# 2. **パスワードに利用可能な文字の制限について**
#
#    XYZシステムのパスワード設定における使用可能な文字の種類と文字数制限については以下の通りです：
#
#    - パスワードは最低8文字以上の長さが必要です。
#    - 大文字と小文字の両方を含む必要があります。
#    - 少なくとも1つの数字を含む必要があります。
#    - 少なくとも1つの特殊文字（例: !@#$%^&* など）を含む必要があります。
#
#    これらの条件を満たすことで、安全かつシステムでの認証エラーを防ぐことができます。
#
# ご不明な点がございましたら、引き続きご連絡ください。どうぞよろしくお願いいたします。
