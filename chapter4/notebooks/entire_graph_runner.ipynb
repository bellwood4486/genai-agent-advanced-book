# %%
from src.agent import HelpDeskAgent
from src.configs import Settings
from src.tools.search_xyz_manual import search_xyz_manual
from src.tools.search_xyz_qa import (
    search_xyz_qa,
)

# %%
settings = Settings()

# %%
agent = HelpDeskAgent(
    settings=settings,
    tools=[search_xyz_manual, search_xyz_qa],
)

# %%
question = """
お世話になっております。

現在、XYZシステムの利用を検討しており、以下の2点についてご教示いただければと存じます。

1. パスワードに利用可能な文字の制限について
当該システムにてパスワードを設定する際、使用可能な文字の範囲（例：英数字、記号、文字数制限など）について詳しい情報をいただけますでしょうか。安全かつシステムでの認証エラーを防ぐため、具体的な仕様を確認したいと考えております。

2. 最新リリースの取得方法について
最新のアップデート情報をどのように確認・取得できるかについてもお教えいただけますと幸いです。

お忙しいところ恐縮ですが、ご対応のほどよろしくお願い申し上げます。

"""

# question = """
# お世話になっております。

# 現在、XYZシステムを利用しており、以下の点についてご教示いただければと存じます。

# 1. 特定のプロジェクトに対してのみ通知を制限する方法について
# 特定のプロジェクトに対してのみ通知を制限する方法についてお教えいただけますと幸いです。

# 2. パスワードに利用可能な文字の制限について
# 当該システムにてパスワードを設定する際、使用可能な文字の範囲（例：英数字、記号、文字数制限など）について詳しい情報をいただけますでしょうか。安全かつシステムでの認証エラーを防ぐため、具体的な仕様を確認したいと考えております。

# お忙しいところ恐縮ですが、ご対応のほどよろしくお願い申し上げます。
# """

# %% [markdown]
# ## ヘルプデスクエージェント全体を実行します

# %%
result = agent.run_agent(question)
# Out:
# 2026-04-20 10:26:57,211 INFO 🚀 Starting plan generation process...
# 2026-04-20 10:26:57,212 INFO Sending request to OpenAI...
# 2026-04-20 10:26:59,633 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:26:59,644 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:26:59,644 INFO Plan generation complete!
# 2026-04-20 10:26:59,663 INFO 🚀 Starting tool selection process...
# 2026-04-20 10:26:59,664 INFO 🚀 Starting tool selection process...
# 2026-04-20 10:26:59,664 INFO 🚀 Starting tool selection process...
# 2026-04-20 10:26:59,665 INFO 🚀 Starting tool selection process...
# 2026-04-20 10:26:59,834 INFO Sending request to OpenAI...
# 2026-04-20 10:26:59,835 INFO Sending request to OpenAI...
# 2026-04-20 10:26:59,836 INFO Sending request to OpenAI...
# 2026-04-20 10:26:59,836 INFO Sending request to OpenAI...
# 2026-04-20 10:27:00,811 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:00,813 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:00,814 INFO Tool selection complete!
# 2026-04-20 10:27:00,816 INFO 🚀 Starting tool execution process...
# 2026-04-20 10:27:00,816 INFO Searching XYZ manual by keyword: {"keywords":"最新リリース 取得方法"}
# 2026-04-20 10:27:00,865 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.048s]
# 2026-04-20 10:27:00,866 INFO Search results: 10 hits
# 2026-04-20 10:27:00,866 INFO Finished searching XYZ manual by keyword
# 2026-04-20 10:27:00,866 INFO Tool execution complete!
# 2026-04-20 10:27:00,868 INFO 🚀 Starting subtask answer creation process...
# 2026-04-20 10:27:00,868 INFO Sending request to OpenAI...
# 2026-04-20 10:27:01,254 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:01,261 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:01,261 INFO Tool selection complete!
# 2026-04-20 10:27:01,265 INFO 🚀 Starting tool execution process...
# 2026-04-20 10:27:01,266 INFO Searching XYZ manual by keyword: {"keywords":"最新リリース情報 確認方法"}
# 2026-04-20 10:27:01,287 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.020s]
# 2026-04-20 10:27:01,288 INFO Search results: 10 hits
# 2026-04-20 10:27:01,288 INFO Finished searching XYZ manual by keyword
# 2026-04-20 10:27:01,288 INFO Tool execution complete!
# 2026-04-20 10:27:01,291 INFO 🚀 Starting subtask answer creation process...
# 2026-04-20 10:27:01,291 INFO Sending request to OpenAI...
# 2026-04-20 10:27:01,323 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:01,325 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:01,325 INFO Tool selection complete!
# 2026-04-20 10:27:01,327 INFO 🚀 Starting tool execution process...
# 2026-04-20 10:27:01,328 INFO Searching XYZ manual by keyword: {"keywords":"パスワード 使用可能な文字 XYZシステム"}
# 2026-04-20 10:27:01,349 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.020s]
# 2026-04-20 10:27:01,349 INFO Search results: 10 hits
# 2026-04-20 10:27:01,349 INFO Finished searching XYZ manual by keyword
# 2026-04-20 10:27:01,350 INFO Tool execution complete!
# 2026-04-20 10:27:01,352 INFO 🚀 Starting subtask answer creation process...
# 2026-04-20 10:27:01,352 INFO Sending request to OpenAI...
# 2026-04-20 10:27:02,047 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:02,050 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:02,050 INFO Tool selection complete!
# 2026-04-20 10:27:02,053 INFO 🚀 Starting tool execution process...
# 2026-04-20 10:27:02,054 INFO Searching XYZ manual by keyword: {"keywords":"パスワード 文字数制限"}
# 2026-04-20 10:27:02,070 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.016s]
# 2026-04-20 10:27:02,070 INFO Search results: 7 hits
# 2026-04-20 10:27:02,071 INFO Finished searching XYZ manual by keyword
# 2026-04-20 10:27:02,071 INFO Tool execution complete!
# 2026-04-20 10:27:02,074 INFO 🚀 Starting subtask answer creation process...
# 2026-04-20 10:27:02,074 INFO Sending request to OpenAI...
# 2026-04-20 10:27:02,753 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:02,754 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:02,755 INFO Subtask answer creation complete!
# 2026-04-20 10:27:02,757 INFO 🚀 Starting reflection process...
# 2026-04-20 10:27:02,758 INFO Sending request to OpenAI...
# 2026-04-20 10:27:02,805 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:02,809 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:02,809 INFO Subtask answer creation complete!
# 2026-04-20 10:27:02,811 INFO 🚀 Starting reflection process...
# 2026-04-20 10:27:02,811 INFO Sending request to OpenAI...
# 2026-04-20 10:27:02,951 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:02,953 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:02,954 INFO Subtask answer creation complete!
# 2026-04-20 10:27:02,956 INFO 🚀 Starting reflection process...
# 2026-04-20 10:27:02,956 INFO Sending request to OpenAI...
# 2026-04-20 10:27:03,879 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:03,884 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:03,884 INFO Reflection complete!
# 2026-04-20 10:27:04,006 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:04,007 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:04,008 INFO Subtask answer creation complete!
# 2026-04-20 10:27:04,011 INFO 🚀 Starting reflection process...
# 2026-04-20 10:27:04,012 INFO Sending request to OpenAI...
# 2026-04-20 10:27:04,556 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:04,565 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:04,566 INFO Reflection complete!
# 2026-04-20 10:27:04,584 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:04,585 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:04,588 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:04,588 INFO Reflection complete!
# 2026-04-20 10:27:04,592 INFO 🚀 Starting tool selection process...
# 2026-04-20 10:27:04,593 INFO Sending request to OpenAI...
# 2026-04-20 10:27:04,602 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:04,602 INFO Reflection complete!
# 2026-04-20 10:27:05,415 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:05,417 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:05,417 INFO Tool selection complete!
# 2026-04-20 10:27:05,421 INFO 🚀 Starting tool execution process...
# 2026-04-20 10:27:05,422 INFO Searching XYZ QA by query: {"query":"最新リリース 取得方法"}
# 2026-04-20 10:27:05,456 INFO Generating embedding vector from input query
# 2026-04-20 10:27:07,499 INFO HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-04-20 10:27:07,517 INFO HTTP Request: POST http://localhost:6333/collections/documents/points/query "HTTP/1.1 200 OK"
# 2026-04-20 10:27:07,519 INFO Search results: 3 hits
# 2026-04-20 10:27:07,519 INFO Finished searching XYZ QA by query
# 2026-04-20 10:27:07,519 INFO Tool execution complete!
# 2026-04-20 10:27:07,522 INFO 🚀 Starting subtask answer creation process...
# 2026-04-20 10:27:07,522 INFO Sending request to OpenAI...
# 2026-04-20 10:27:08,999 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:09,003 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:09,004 INFO Subtask answer creation complete!
# 2026-04-20 10:27:09,009 INFO 🚀 Starting reflection process...
# 2026-04-20 10:27:09,010 INFO Sending request to OpenAI...
# 2026-04-20 10:27:10,201 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:10,209 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:10,210 INFO Reflection complete!
# 2026-04-20 10:27:10,217 INFO 🚀 Starting tool selection process...
# 2026-04-20 10:27:10,221 INFO Sending request to OpenAI...
# 2026-04-20 10:27:10,943 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:10,946 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:10,947 INFO Tool selection complete!
# 2026-04-20 10:27:10,952 INFO 🚀 Starting tool execution process...
# 2026-04-20 10:27:10,954 INFO Searching XYZ manual by keyword: {"keywords":"サポートチーム 問い合わせ"}
# 2026-04-20 10:27:10,971 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.016s]
# 2026-04-20 10:27:10,972 INFO Search results: 5 hits
# 2026-04-20 10:27:10,972 INFO Finished searching XYZ manual by keyword
# 2026-04-20 10:27:10,973 INFO Tool execution complete!
# 2026-04-20 10:27:10,976 INFO 🚀 Starting subtask answer creation process...
# 2026-04-20 10:27:10,977 INFO Sending request to OpenAI...
# 2026-04-20 10:27:11,182 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-04-20 10:27:11,183 INFO Retrying request to /chat/completions in 1.512000 seconds
# 2026-04-20 10:27:14,838 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:14,841 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:14,842 INFO Subtask answer creation complete!
# 2026-04-20 10:27:14,847 INFO 🚀 Starting reflection process...
# 2026-04-20 10:27:14,847 INFO Sending request to OpenAI...
# 2026-04-20 10:27:15,064 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-04-20 10:27:15,065 INFO Retrying request to /chat/completions in 4.122000 seconds
# 2026-04-20 10:27:19,390 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-04-20 10:27:19,391 INFO Retrying request to /chat/completions in 0.748000 seconds
# 2026-04-20 10:27:22,005 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:22,008 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:22,009 INFO Reflection complete!
# 2026-04-20 10:27:22,016 INFO 🚀 Starting final answer creation process...
# 2026-04-20 10:27:22,017 INFO Sending request to OpenAI...
# 2026-04-20 10:27:22,224 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# 2026-04-20 10:27:22,226 INFO Retrying request to /chat/completions in 2.046000 seconds
# 2026-04-20 10:27:29,173 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-20 10:27:29,176 INFO ✅ Successfully received response from OpenAI.
# 2026-04-20 10:27:29,176 INFO Final answer creation complete!

# %%
# 回答
print(result.answer)
# Out:
# お世話になっております。
#
# XYZシステムの利用に関するご質問について、以下の通り回答いたします。
#
# 1. **パスワードに利用可能な文字の制限について**:
#    - パスワードは最低8文字以上である必要があります。
#    - 大文字と小文字の両方を含める必要があります。
#    - 少なくとも1つの数字を含める必要があります。
#    - 少なくとも1つの特殊文字（例: !@#$%^&* など）を含める必要があります。
#
#    これらの要件を満たすことで、安全かつ認証エラーを防ぐパスワードを設定することができます。
#
# 2. **最新リリースの取得方法について**:
#    - 最新のリリース情報は、毎月のシステムアップデートや新機能の説明が記載されたリリースノートを確認することで得ることができます。リリースノートは、XYZシステム統合ユーザーマニュアルに記載されています。
#    - 具体的な最新リリースの取得方法についての詳細は見つかりませんでしたが、サポートチームへの問い合わせが推奨されています。オンラインヘルプセンターが24時間365日利用可能ですので、そちらを通じてサポートチームに直接お問い合わせいただくことが最も確実です。
#
# ご不明な点がございましたら、引き続きサポートいたしますので、お気軽にご連絡ください。どうぞよろしくお願いいたします。
