# %%
from src.agent import HelpDeskAgent
from src.configs import Settings
from src.tools.search_xyz_manual import search_xyz_manual
from src.tools.search_xyz_qa import (
    search_xyz_qa,
)

# %%
settings = Settings()

# %%
agent = HelpDeskAgent(
    settings=settings,
    tools=[search_xyz_manual, search_xyz_qa],
)

# %%
question = """
お世話になっております。

現在、XYZシステムの利用を検討しており、以下の2点についてご教示いただければと存じます。

1. パスワードに利用可能な文字の制限について
当該システムにてパスワードを設定する際、使用可能な文字の範囲（例：英数字、記号、文字数制限など）について詳しい情報をいただけますでしょうか。安全かつシステムでの認証エラーを防ぐため、具体的な仕様を確認したいと考えております。

2. 最新リリースの取得方法について
最新のアップデート情報をどのように確認・取得できるかについてもお教えいただけますと幸いです。

お忙しいところ恐縮ですが、ご対応のほどよろしくお願い申し上げます。

"""

# question = """
# お世話になっております。

# 現在、XYZシステムを利用しており、以下の点についてご教示いただければと存じます。

# 1. 特定のプロジェクトに対してのみ通知を制限する方法について
# 特定のプロジェクトに対してのみ通知を制限する方法についてお教えいただけますと幸いです。

# 2. パスワードに利用可能な文字の制限について
# 当該システムにてパスワードを設定する際、使用可能な文字の範囲（例：英数字、記号、文字数制限など）について詳しい情報をいただけますでしょうか。安全かつシステムでの認証エラーを防ぐため、具体的な仕様を確認したいと考えております。

# お忙しいところ恐縮ですが、ご対応のほどよろしくお願い申し上げます。
# """

# %% [markdown]
# ## ヘルプデスクエージェント全体を実行します

# %%
result = agent.run_agent(question)
# Out:
# 2026-04-19 19:49:23,546 INFO 🚀 Starting plan generation process...
# 2026-04-19 19:49:23,546 INFO Sending request to OpenAI...
# 2026-04-19 19:49:25,716 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:25,725 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:25,726 INFO Plan generation complete!
# 2026-04-19 19:49:25,751 INFO 🚀 Starting tool selection process...
# 2026-04-19 19:49:25,752 INFO 🚀 Starting tool selection process...
# 2026-04-19 19:49:25,758 INFO Sending request to OpenAI...
# 2026-04-19 19:49:25,758 INFO Sending request to OpenAI...
# 2026-04-19 19:49:27,339 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:27,344 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:27,345 INFO Tool selection complete!
# 2026-04-19 19:49:27,349 INFO 🚀 Starting tool execution process...
# 2026-04-19 19:49:27,350 INFO Searching XYZ manual by keyword: {"keywords":"パスワード 設定 文字制限"}
# 2026-04-19 19:49:27,371 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:27,373 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:27,373 INFO Tool selection complete!
# 2026-04-19 19:49:27,376 INFO 🚀 Starting tool execution process...
# 2026-04-19 19:49:27,377 INFO Searching XYZ manual by keyword: {"keywords":"最新リリース情報 取得方法"}
# 2026-04-19 19:49:27,393 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.042s]
# 2026-04-19 19:49:27,394 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.016s]
# 2026-04-19 19:49:27,394 INFO Search results: 10 hits
# 2026-04-19 19:49:27,395 INFO Search results: 10 hits
# 2026-04-19 19:49:27,395 INFO Finished searching XYZ manual by keyword
# 2026-04-19 19:49:27,395 INFO Finished searching XYZ manual by keyword
# 2026-04-19 19:49:27,395 INFO Tool execution complete!
# 2026-04-19 19:49:27,396 INFO Tool execution complete!
# 2026-04-19 19:49:27,398 INFO 🚀 Starting subtask answer creation process...
# 2026-04-19 19:49:27,400 INFO Sending request to OpenAI...
# 2026-04-19 19:49:27,401 INFO 🚀 Starting subtask answer creation process...
# 2026-04-19 19:49:27,404 INFO Sending request to OpenAI...
# 2026-04-19 19:49:29,245 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:29,246 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:29,246 INFO Subtask answer creation complete!
# 2026-04-19 19:49:29,248 INFO 🚀 Starting reflection process...
# 2026-04-19 19:49:29,249 INFO Sending request to OpenAI...
# 2026-04-19 19:49:29,567 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:29,572 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:29,572 INFO Subtask answer creation complete!
# 2026-04-19 19:49:29,574 INFO 🚀 Starting reflection process...
# 2026-04-19 19:49:29,575 INFO Sending request to OpenAI...
# 2026-04-19 19:49:30,965 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:30,968 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:30,969 INFO Reflection complete!
# 2026-04-19 19:49:31,582 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:31,586 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:31,587 INFO Reflection complete!
# 2026-04-19 19:49:31,593 INFO 🚀 Starting tool selection process...
# 2026-04-19 19:49:31,598 INFO Sending request to OpenAI...
# 2026-04-19 19:49:32,684 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:32,688 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:32,688 INFO Tool selection complete!
# 2026-04-19 19:49:32,694 INFO 🚀 Starting tool execution process...
# 2026-04-19 19:49:32,696 INFO Searching XYZ manual by keyword: {"keywords":"XYZシステム リリースノート 取得方法"}
# 2026-04-19 19:49:32,731 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.034s]
# 2026-04-19 19:49:32,732 INFO Search results: 10 hits
# 2026-04-19 19:49:32,732 INFO Finished searching XYZ manual by keyword
# 2026-04-19 19:49:32,733 INFO Tool execution complete!
# 2026-04-19 19:49:32,736 INFO 🚀 Starting subtask answer creation process...
# 2026-04-19 19:49:32,737 INFO Sending request to OpenAI...
# 2026-04-19 19:49:35,473 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:35,477 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:35,477 INFO Subtask answer creation complete!
# 2026-04-19 19:49:35,483 INFO 🚀 Starting reflection process...
# 2026-04-19 19:49:35,483 INFO Sending request to OpenAI...
# 2026-04-19 19:49:36,530 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:36,533 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:36,534 INFO Reflection complete!
# 2026-04-19 19:49:36,545 INFO 🚀 Starting final answer creation process...
# 2026-04-19 19:49:36,546 INFO Sending request to OpenAI...
# 2026-04-19 19:49:40,022 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-19 19:49:40,027 INFO ✅ Successfully received response from OpenAI.
# 2026-04-19 19:49:40,028 INFO Final answer creation complete!

# %%
# 回答
print(result.answer)
# Out:
# お世話になっております。
#
# XYZシステムの利用をご検討いただき、ありがとうございます。ご質問にお答えいたします。
#
# 1. **パスワードに利用可能な文字の制限について**:
#    - パスワードは最低8文字以上である必要があります。
#    - 大文字と小文字の両方を含む必要があります。
#    - 少なくとも1つの数字を含む必要があります。
#    - 少なくとも1つの特殊文字（例: !@#$%^&*）を含む必要があります。
#
#    これらの基準を満たさないパスワードは、システムによって拒否されますのでご注意ください。
#
# 2. **最新リリースの取得方法について**:
#    - XYZシステムの最新のアップデート情報や新機能の説明は、毎月発行される「リリースノート」で提供されています。
#    - リリースノートは、XYZシステムの公式ウェブサイトやユーザーポータルからアクセス可能です。
#    - ユーザーは、これらのプラットフォームにログインし、リリースノートをダウンロードまたは閲覧することで、最新の情報を確認することができます。
#
# ご不明な点がございましたら、どうぞお気軽にお問い合わせください。引き続き、XYZシステムのご利用をお待ちしております。
